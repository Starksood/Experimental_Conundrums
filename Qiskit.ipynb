# %%
Last login: Thu Nov 18 22:00:01 on ttys000
(base) macbook@Macbooks-MBP ~ % qiskit._version_
zsh: command not found: qiskit._version_
(base) macbook@Macbooks-MBP ~ % python --version
Python 3.8.8
(base) macbook@Macbooks-MBP ~ % pip install qiskit
Collecting qiskit
  Downloading qiskit-0.32.0.tar.gz (13 kB)
Collecting qiskit-terra==0.18.3
  Downloading qiskit_terra-0.18.3-cp38-cp38-macosx_10_9_x86_64.whl (5.3 MB)
     |████████████████████████████████| 5.3 MB 2.8 MB/s 
Collecting qiskit-aer==0.9.1
  Downloading qiskit_aer-0.9.1-cp38-cp38-macosx_10_9_x86_64.whl (8.6 MB)
     |████████████████████████████████| 8.6 MB 14.2 MB/s 
Collecting qiskit-ibmq-provider==0.18.0
  Downloading qiskit_ibmq_provider-0.18.0-py3-none-any.whl (237 kB)
     |████████████████████████████████| 237 kB 5.8 MB/s 
Collecting qiskit-ignis==0.6.0
  Using cached qiskit_ignis-0.6.0-py3-none-any.whl (207 kB)
Collecting qiskit-aqua==0.9.5
  Using cached qiskit_aqua-0.9.5-py3-none-any.whl (2.1 MB)
Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aer==0.9.1->qiskit) (1.6.2)
Requirement already satisfied: numpy>=1.16.3 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aer==0.9.1->qiskit) (1.20.1)
Requirement already satisfied: psutil>=5 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (5.8.0)
Collecting docplex>=2.21.207
  Using cached docplex-2.22.213.tar.gz (634 kB)
Requirement already satisfied: h5py<3.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (2.10.0)
Collecting fastdtw<=0.3.4
  Using cached fastdtw-0.3.4.tar.gz (133 kB)
Collecting quandl
  Downloading Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (52.0.0.post20210125)
Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.24.1)
Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.2.4)
Collecting retworkx>=0.8.0
  Downloading retworkx-0.10.2-cp38-cp38-macosx_10_9_x86_64.whl (1.1 MB)
     |████████████████████████████████| 1.1 MB 11.9 MB/s 
Collecting yfinance>=0.1.62
  Downloading yfinance-0.1.66-py2.py3-none-any.whl (25 kB)
Collecting dlx<=1.0.4
  Using cached dlx-1.0.4.tar.gz (5.5 kB)
Requirement already satisfied: sympy>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.8)
Collecting websocket-client>=1.0.1
  Using cached websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (2.8.1)
Collecting requests-ntlm>=1.1.0
  Using cached requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
Requirement already satisfied: urllib3>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (1.26.4)
Requirement already satisfied: requests>=2.19 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (2.25.1)
Collecting dill>=0.3
  Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
Collecting fastjsonschema>=2.10
  Using cached fastjsonschema-2.15.1-py3-none-any.whl (21 kB)
Collecting python-constraint>=1.4
  Using cached python-constraint-1.4.0.tar.bz2 (18 kB)
Requirement already satisfied: ply>=3.10 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (3.11)
Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (3.2.0)
Collecting tweedledum<2.0,>=1.1
  Downloading tweedledum-1.1.1-cp38-cp38-macosx_10_15_x86_64.whl (961 kB)
     |████████████████████████████████| 961 kB 10.7 MB/s 
Collecting symengine>0.7
  Downloading symengine-0.8.1-cp38-cp38-macosx_10_9_x86_64.whl (17.7 MB)
     |████████████████████████████████| 17.7 MB 20.3 MB/s 
Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from docplex>=2.21.207->qiskit-aqua==0.9.5->qiskit) (1.15.0)
Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (20.3.0)
Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (0.17.3)
Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.0->qiskit) (2.10)
Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.0->qiskit) (4.0.0)
Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.0->qiskit) (2020.12.5)
Collecting ntlm-auth>=1.0.2
  Using cached ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
Requirement already satisfied: cryptography>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (3.4.7)
Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.8/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (1.14.5)
Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (2.20)
Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (1.0.1)
Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (2.1.0)
Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.8/site-packages (from sympy>=1.3->qiskit-aqua==0.9.5->qiskit) (1.2.1)
Requirement already satisfied: lxml>=4.5.1 in /opt/anaconda3/lib/python3.8/site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (4.6.3)
Collecting multitasking>=0.0.7
  Downloading multitasking-0.0.10.tar.gz (8.2 kB)
Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->qiskit-aqua==0.9.5->qiskit) (2021.1)
Requirement already satisfied: more-itertools in /opt/anaconda3/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (8.7.0)
Collecting inflection>=0.3.1
  Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
Building wheels for collected packages: qiskit, dlx, docplex, fastdtw, python-constraint, multitasking
  Building wheel for qiskit (setup.py) ... done
  Created wheel for qiskit: filename=qiskit-0.32.0-py3-none-any.whl size=11756 sha256=e1788b0d34dabc4b5aba29e07de1c54968a3cf745eaf4a849e5a56f075c0b5ca
  Stored in directory: /Users/macbook/Library/Caches/pip/wheels/e6/95/f5/163a46b5a43b9a64e629935771ac007802e74f7fa35b9b44c5
  Building wheel for dlx (setup.py) ... done
  Created wheel for dlx: filename=dlx-1.0.4-py3-none-any.whl size=5709 sha256=7069dd2cb24994d502f7f90ee7b89762df4e28bd09370fa72140a9eef6b5aab2
  Stored in directory: /Users/macbook/Library/Caches/pip/wheels/c4/03/f9/7afbf40e0c3d6928d16bcadb46264a6e68704998ec72f7ea13
  Building wheel for docplex (setup.py) ... done
  Created wheel for docplex: filename=docplex-2.22.213-py3-none-any.whl size=696852 sha256=8db49b7f8758464caf27399871f0b11763f3a8ec547b96ad0293683ea7a7655a
  Stored in directory: /Users/macbook/Library/Caches/pip/wheels/35/3e/11/e31bf877e1965b75dc2f3de4ec2d5c9d1680c6f803ef76ed9f
  Building wheel for fastdtw (setup.py) ... done
  Created wheel for fastdtw: filename=fastdtw-0.3.4-cp38-cp38-macosx_10_9_x86_64.whl size=96606 sha256=b06d2a7e9b45b041aa0dc8060c42a4d2ed5992e7b655b08e3566ef8ea6432fff
  Stored in directory: /Users/macbook/Library/Caches/pip/wheels/e9/ac/30/c962f9d759dd68cb5482727c44441fdfb48040fdbe983857e8
  Building wheel for python-constraint (setup.py) ... done
  Created wheel for python-constraint: filename=python_constraint-1.4.0-py2.py3-none-any.whl size=24079 sha256=707a2dc815bd06fe75ddcf271ccf5ef0fbcae29067f4fad81116d1124be7ac82
  Stored in directory: /Users/macbook/Library/Caches/pip/wheels/86/ba/5c/4e9115777de42c6a2e1ca77ef7c9d0d479254c5080341b55c5
  Building wheel for multitasking (setup.py) ... done
  Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8488 sha256=4200c40eb494409545e48f514f808abcdb3639f0ec4f1afa741d0231b3a6a570
  Stored in directory: /Users/macbook/Library/Caches/pip/wheels/21/c9/66/b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
Successfully built qiskit dlx docplex fastdtw python-constraint multitasking
Installing collected packages: tweedledum, symengine, retworkx, python-constraint, fastjsonschema, dill, qiskit-terra, ntlm-auth, multitasking, inflection, yfinance, websocket-client, requests-ntlm, quandl, qiskit-ignis, fastdtw, docplex, dlx, qiskit-ibmq-provider, qiskit-aqua, qiskit-aer, qiskit
Successfully installed dill-0.3.4 dlx-1.0.4 docplex-2.22.213 fastdtw-0.3.4 fastjsonschema-2.15.1 inflection-0.5.1 multitasking-0.0.10 ntlm-auth-1.5.0 python-constraint-1.4.0 qiskit-0.32.0 qiskit-aer-0.9.1 qiskit-aqua-0.9.5 qiskit-ibmq-provider-0.18.0 qiskit-ignis-0.6.0 qiskit-terra-0.18.3 quandl-3.7.0 requests-ntlm-1.1.0 retworkx-0.10.2 symengine-0.8.1 tweedledum-1.1.1 websocket-client-1.2.1 yfinance-0.1.66
(base) macbook@Macbooks-MBP ~ % from qiskit import IBMQ
from: can't read /var/mail/qiskit
(base) macbook@Macbooks-MBP ~ % pip install -U qiskit
Requirement already satisfied: qiskit in /opt/anaconda3/lib/python3.8/site-packages (0.32.0)
Requirement already satisfied: qiskit-ibmq-provider==0.18.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.18.0)
Requirement already satisfied: qiskit-aer==0.9.1 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.9.1)
Requirement already satisfied: qiskit-terra==0.18.3 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.18.3)
Requirement already satisfied: qiskit-aqua==0.9.5 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.9.5)
Requirement already satisfied: qiskit-ignis==0.6.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit) (0.6.0)
Requirement already satisfied: numpy>=1.16.3 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aer==0.9.1->qiskit) (1.20.1)
Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aer==0.9.1->qiskit) (1.6.2)
Requirement already satisfied: yfinance>=0.1.62 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.1.66)
Requirement already satisfied: retworkx>=0.8.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.10.2)
Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.2.4)
Requirement already satisfied: psutil>=5 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (5.8.0)
Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.24.1)
Requirement already satisfied: sympy>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.8)
Requirement already satisfied: dlx<=1.0.4 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (1.0.4)
Requirement already satisfied: fastdtw<=0.3.4 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (0.3.4)
Requirement already satisfied: docplex>=2.21.207 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (2.22.213)
Requirement already satisfied: setuptools>=40.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (52.0.0.post20210125)
Requirement already satisfied: quandl in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (3.7.0)
Requirement already satisfied: h5py<3.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-aqua==0.9.5->qiskit) (2.10.0)
Requirement already satisfied: requests>=2.19 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (2.25.1)
Requirement already satisfied: python-dateutil>=2.8.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (2.8.1)
Requirement already satisfied: requests-ntlm>=1.1.0 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (1.1.0)
Requirement already satisfied: urllib3>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (1.26.4)
Requirement already satisfied: websocket-client>=1.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-ibmq-provider==0.18.0->qiskit) (1.2.1)
Requirement already satisfied: python-constraint>=1.4 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (1.4.0)
Requirement already satisfied: dill>=0.3 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (0.3.4)
Requirement already satisfied: fastjsonschema>=2.10 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (2.15.1)
Requirement already satisfied: ply>=3.10 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (3.11)
Requirement already satisfied: tweedledum<2.0,>=1.1 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (1.1.1)
Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (3.2.0)
Requirement already satisfied: symengine>0.7 in /opt/anaconda3/lib/python3.8/site-packages (from qiskit-terra==0.18.3->qiskit) (0.8.1)
Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from docplex>=2.21.207->qiskit-aqua==0.9.5->qiskit) (1.15.0)
Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (0.17.3)
Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=2.6->qiskit-terra==0.18.3->qiskit) (20.3.0)
Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.0->qiskit) (2.10)
Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.0->qiskit) (4.0.0)
Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.18.0->qiskit) (2020.12.5)
Requirement already satisfied: cryptography>=1.3 in /opt/anaconda3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (3.4.7)
Requirement already satisfied: ntlm-auth>=1.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (1.5.0)
Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.8/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (1.14.5)
Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.18.0->qiskit) (2.20)
Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (1.0.1)
Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.9.5->qiskit) (2.1.0)
Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.8/site-packages (from sympy>=1.3->qiskit-aqua==0.9.5->qiskit) (1.2.1)
Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/lib/python3.8/site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (0.0.10)
Requirement already satisfied: lxml>=4.5.1 in /opt/anaconda3/lib/python3.8/site-packages (from yfinance>=0.1.62->qiskit-aqua==0.9.5->qiskit) (4.6.3)
Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas->qiskit-aqua==0.9.5->qiskit) (2021.1)
Requirement already satisfied: inflection>=0.3.1 in /opt/anaconda3/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (0.5.1)
Requirement already satisfied: more-itertools in /opt/anaconda3/lib/python3.8/site-packages (from quandl->qiskit-aqua==0.9.5->qiskit) (8.7.0)
(base) macbook@Macbooks-MBP ~ % from qiskit import IMBQ
from: can't read /var/mail/qiskit
(base) macbook@Macbooks-MBP ~ % IMBQ.save_account('***********************************************************************************************************')
zsh: unknown file attribute: 9
(base) macbook@Macbooks-MBP ~ % activate Qiskitenv
Could not find conda environment: Qiskitenv
You can list all discoverable environments with `conda info --envs`.

(base) macbook@Macbooks-MBP ~ % conda info --envs
# conda environments:
#
base                  *  /opt/anaconda3
Qiskit                   /opt/anaconda3/envs/Qiskit
boa                      /opt/anaconda3/envs/boa

(base) macbook@Macbooks-MBP ~ % from qiskit import IBMQ
from: can't read /var/mail/qiskit
(base) macbook@Macbooks-MBP ~ % from Qiskit import IBMQ
from: can't read /var/mail/Qiskit
(base) macbook@Macbooks-MBP ~ % from qiskit import QuantumCircuit
from: can't read /var/mail/qiskit
(base) macbook@Macbooks-MBP ~ % #!/usr/bin/env python
zsh: event not found: /usr/bin/env
(base) macbook@Macbooks-MBP ~ % python
Python 3.8.8 (default, Apr 13 2021, 12:59:45) 
[Clang 10.0.0 ] :: Anaconda, Inc. on darwin
Type "help", "copyright", "credits" or "license" for more information.
>>> from qiskit import IBMQ
IBMQ.save_account('>>> IBMQ.save_account('********************************************************************************************************************')
>>> from qiskit import IBMQ
>>> provider = IBMQ.load_account()
>>> pip install qiskit[visualization]
  File "<stdin>", line 1
    pip install qiskit[visualization]
        ^
SyntaxError: invalid syntax
>>> pip install 'qiskit[visualization]'
  File "<stdin>", line 1
    pip install 'qiskit[visualization]'
        ^
SyntaxError: invalid syntax
>>> from qiskit import QuantumCircuit
>>> qc = QuantumCircuit(3, 30
... qc = QuantumCircuit(3, 3)
  File "<stdin>", line 2
    qc = QuantumCircuit(3, 3)
    ^
SyntaxError: invalid syntax
>>> from qc = QuantumCircuit(3, 3)
  File "<stdin>", line 1
    from qc = QuantumCircuit(3, 3)
            ^
SyntaxError: invalid syntax
>>> from qiskit import QuantumCircuit
>>> qc = QuantumCircuit(3, 3)
>>> qc.measure([0,1,2], [0,1,2])
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff064319130>
>>> qc.draw()
     ┌─┐      
q_0: ┤M├──────
     └╥┘┌─┐   
q_1: ─╫─┤M├───
      ║ └╥┘┌─┐
q_2: ─╫──╫─┤M├
      ║  ║ └╥┘
c: 3/═╩══╩══╩═
      0  1  2 
>>> from qiskit.providers.aer import AerSimulator
sim = AerSimulator(>>> sim = AerSimulator()
>>> sim = AerSimulator()
>>> job = sim.run(qc)
>>> result = job.result()
>>> result.get_counts()
{'000': 1024}
>>> qc = QuantumCircuit(3, 3)
>>> qc.X([0,1])
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
AttributeError: 'QuantumCircuit' object has no attribute 'X'
>>> qc = QuantumCircuit(3,3)
>>> qc.x([0,1])
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069903760>
>>> qc.measure([0,1,2], [0,1,2])
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069f932b0>
>>> qc.draw
<bound method QuantumCircuit.draw of <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7ff064068670>>
>>> qc.draw()
     ┌───┐┌─┐   
q_0: ┤ X ├┤M├───
     ├───┤└╥┘┌─┐
q_1: ┤ X ├─╫─┤M├
     └┬─┬┘ ║ └╥┘
q_2: ─┤M├──╫──╫─
      └╥┘  ║  ║ 
c: 3/══╩═══╩══╩═
       2   0  1 
>>> job = sim.run(qc)
>>> result = job.result()
>>> result.get_counts()
{'011': 1024}
>>> qc = QuantumCircuit(2, 2)
>>> qc.x(0)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff064068670>
>>> qc.cx(0,1)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff06992d130>
>>> qc.measure([0,1], [0,1])
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069903760>
>>> display(qc.draw())
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
NameError: name 'display' is not defined
>>> job = sim.run(qc)
>>> result = job.result()
>>> print("Result: ", result.get_counts())
Result:  {'11': 1024}
>>> test_qc = QuantumCircuit(4, 2)
>>> test_qc.x(0)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff06992d4c0>
>>> test_qc.x(1)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff06992d2e0>
>>> test_qc.cx(0,2)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069f934c0>
>>> test_qc.cx(1,2)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069f93a30>
>>> test_qc.ccx(0,1,3)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069f93820>
>>> test_qc.measure(2,0)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069f93c70>
>>> test_qc.measure(3,1)
<qiskit.circuit.instructionset.InstructionSet object at 0x7ff069f934c0>
>>> test_qc.draw()
     ┌───┐                     
q_0: ┤ X ├──■─────────■────────
     ├───┤  │         │        
q_1: ┤ X ├──┼────■────■────────
     └───┘┌─┴─┐┌─┴─┐  │  ┌─┐   
q_2: ─────┤ X ├┤ X ├──┼──┤M├───
          └───┘└───┘┌─┴─┐└╥┘┌─┐
q_3: ───────────────┤ X ├─╫─┤M├
                    └───┘ ║ └╥┘
c: 2/═════════════════════╩══╩═
                          0  1 
>>> job = sim.run(test_qc)
>>> result = job.result()
>>> result.get_counts()
{'10': 1024}
>>>
